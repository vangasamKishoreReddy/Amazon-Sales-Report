# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"Amazon Sale Report.csv", encoding='ISO-8859-1')

# %%
data.shape
# Out:
# (128976, 21)

# %%
data.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
data.describe()
# Out:
#                index            Qty         Amount  ship-postal-code  New  \
# count  128976.000000  128976.000000  121176.000000     128941.000000  0.0
# mean    64486.130427       0.904401     648.562176     463945.677744  NaN
# std     37232.897832       0.313368     281.185041     191458.488954  NaN
# min         0.000000       0.000000       0.000000     110001.000000  NaN
# 25%     32242.750000       1.000000     449.000000     382421.000000  NaN
# 50%     64486.500000       1.000000     605.000000     500033.000000  NaN
# 75%     96730.250000       1.000000     788.000000     600024.000000  NaN
# max    128974.000000      15.000000    5584.000000     989898.000000  NaN
#
#        PendingS
# count       0.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
data.isnull().sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.Data Loading

# %%
df = pd.read_csv(r"cleaned_dataset.csv")

# %%
df.shape
# Out:
# (128976, 18)

# %% [markdown]
# ## 2.Basic Data Inspection

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128971  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128972  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128973  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128974  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128975  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel ship-service-level Category Size Courier Status  Qty  \
# 128971     Amazon.in          Expedited    Shirt   XL        Shipped    1
# 128972     Amazon.in          Expedited  T-shirt    M        Shipped    1
# 128973     Amazon.in          Expedited  Blazzer  XXL        Shipped    1
# 128974     Amazon.in          Expedited  T-shirt   XS        Shipped    1
# 128975     Amazon.in          Expedited  T-shirt    S        Shipped    1
#
#        currency  Amount  ship-city    ship-state ship-postal-code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            128976 non-null  object
#  12  Amount              128976 non-null  float64
#  13  ship-city           128976 non-null  object
#  14  ship-state          128976 non-null  object
# ...

# %%
df.describe()
# Out:
#                index            Qty         Amount
# count  128976.000000  128976.000000  128976.000000
# mean    64486.130427       0.904401     645.927694
# std     37232.897832       0.313368     272.747592
# min         0.000000       0.000000       0.000000
# 25%     32242.750000       1.000000     459.000000
# 50%     64486.500000       1.000000     605.000000
# 75%     96730.250000       1.000000     771.000000
# max    128974.000000      15.000000    5584.000000

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Category               object
# Size                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code       object
# ship-country           object
# B2B                      bool
# dtype: object

# %% [markdown]
# ## 3.Data Cleaning

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# dtype: int64

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
print("\nNumber of Duplicate Rows:", df.duplicated().sum())
# Out:
# Number of Duplicate Rows: 168

# %%
# Drop duplicates if necessary
drop = df.drop_duplicates()

# %%
drop.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    Qty currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
# Display unique values in key categorical columns
categorical_columns = ['ship-service-level', 'Courier Status', 'Fulfilment']
for col in categorical_columns:
    print(f"\nUnique values in {col}: {df[col].unique()}")
# Out:
# Unique values in ship-service-level: ['Standard' 'Expedited']
#
# Unique values in Courier Status: ['On the Way' 'Shipped' 'Cancelled' 'Unshipped']
#
# Unique values in Fulfilment: ['Merchant' 'Amazon']

# %%
# Display the top 10 dates
top_10_dates = df['Date'].value_counts().head(10)
print("\nTop 10 Dates with Most Orders:")
print(top_10_dates)
# Out:
# Top 10 Dates with Most Orders:
# Date
# 05-03-2022    2085
# 05-02-2022    2079
# 05-04-2022    2015
# 04-14-22      1883
# 04-15-22      1853
# 04-20-22      1850
# 04-23-22      1816
# 04-24-22      1810
# 05-01-2022    1809
# 04-16-22      1759
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Data Transformation

# %%
df['Date'].head()
# Out:
# 0    04-30-22
# 1    04-30-22
# 2    04-30-22
# 3    04-30-22
# 4    04-30-22
# Name: Date, dtype: object

# %%
# Display the top 10 dates
top_10_dates = df['Date'].head(5)
print("Top 10 Dates:")
print(top_10_dates)
# Out:
# Top 10 Dates:
# 0    04-30-22
# 1    04-30-22
# 2    04-30-22
# 3    04-30-22
# 4    04-30-22
# Name: Date, dtype: object

# %%
# Display the top 10 shipping service levels
top_10_sizes = df['ship-service-level'].value_counts().head(10)
print("\nTop 10 Shipping Service Levels:")
print(top_10_sizes)
# Out:
# Top 10 Shipping Service Levels:
# ship-service-level
# Expedited    88513
# Standard     40295
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
#
#   Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard  T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard    Shirt  3XL        Shipped
#
#    Qty currency  Amount  ship-city   ship-state ship-postal-code ship-country  \
# 0    0      INR  647.62     MUMBAI  MAHARASHTRA         400081.0           IN
# 1    1      INR  406.00  BENGALURU    KARNATAKA         560085.0           IN
#
#      B2B
# 0  False
# 1  False

# %%
top_10_size=df['ship-service-level'].head(5)
print("Top 10 Sizes:")
print(top_10_size)
# Out:
# Top 10 Sizes:
# 0     Standard
# 1     Standard
# 2    Expedited
# 3     Standard
# 4    Expedited
# Name: ship-service-level, dtype: object

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Category              0
# Size                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B'],
#       dtype='object')

# %% [markdown]
# ##  1. Univariate analysis

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Univariate analysis - Numeric columns (Qty, Amount)
sns.histplot(df['Qty'], kde=True)
plt.title('Distribution of Quantity')
plt.show()

sns.histplot(df['Amount'], kde=True)
plt.title('Distribution of Amount')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y=df['ship-service-level'], order=df['ship-service-level'].value_counts().index)
plt.title("Shipping Service Level Distribution")
plt.xlabel("Count")
plt.ylabel("Ship Service Level")
plt.show()

# %%
# Univariate analysis - Categorical columns (Sales Channel, Category)
sns.countplot(x='Sales Channel', data=df)
plt.title('Sales Channel Distribution')
plt.xticks(rotation=45)
plt.show()

sns.countplot(x='Category', data=df)
plt.title('Category Distribution')
plt.xticks(rotation=45)
plt.show()

sns.countplot(x='ship-country', data=df)
plt.title('Ship-Country Distribution')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 2.  Bivariate Analysis

# %%
plt.figure(figsize=(12, 6))
df['Date'] = pd.to_datetime(df['Date'])  # Convert to datetime format
df.groupby(df['Date'].dt.date)['Order ID'].count().plot(kind='line', marker='o')
plt.title("Orders Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# Bivariate analysis - Scatter Plot
sns.scatterplot(x='Qty', y='Amount', data=df)
plt.title('Relationship Between Quantity and Amount')
plt.show()

# %%
# Bivariate analysis - Heatmap
correlation_matrix = df[['Qty', 'Amount']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Between Qty and Amount')
plt.show()

# %%
# Bivariate analysis - Box Plot (Amount vs Sales Channel)
sns.boxplot(x='Sales Channel', y='Amount', data=df)
plt.title('Amount vs Sales Channel')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 3. Multivariate Analysis:

# %%
# Multivariate analysis - Pair Plot
sns.pairplot(df[['Qty', 'Amount']])
plt.show()

# %%
# Convert columns to numeric, replacing errors with NaN
df['Qty'] = pd.to_numeric(df['Qty'], errors='coerce')
df['Amount'] = pd.to_numeric(df['Amount'], errors='coerce')
df['ship-postal-code'] = pd.to_numeric(df['ship-postal-code'], errors='coerce')

# Now calculate the correlation matrix
correlation_matrix = df[['Qty', 'Amount', 'ship-postal-code']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
